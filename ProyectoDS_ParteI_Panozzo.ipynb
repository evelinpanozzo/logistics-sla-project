# %%
print ("Hello Colab")
# Out:
# Hello Colab

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
df = pd.read_csv("https://raw.githubusercontent.com/evelinpanozzo/logistics-sla-project/refs/heads/main/dynamic_supply_chain_logistics_dataset.csv")

# %% [markdown]
# visualizar la base de datos

# %%
df.head()
# Out:
#              timestamp  vehicle_gps_latitude  vehicle_gps_longitude  \
# 0  2021-01-01 00:00:00             40.375568             -77.014318
# 1  2021-01-01 01:00:00             33.507818            -117.036902
# 2  2021-01-01 02:00:00             30.020640             -75.269224
# 3  2021-01-01 03:00:00             36.649223             -70.190529
# 4  2021-01-01 04:00:00             30.001279             -70.012195
#
#    fuel_consumption_rate  eta_variation_hours  traffic_congestion_level  \
# 0               5.136512             4.998009                  5.927586
# 1               5.101512             0.984929                  1.591992
# 2               5.090803             4.972665                  8.787765
# 3               8.219558             3.095064                  0.045257
# 4               5.000075             3.216077                  8.004851
#
#    warehouse_inventory_level  loading_unloading_time  \
# 0                 985.716862                4.951392
# 1                 396.700206                1.030379
# 2                 832.408935                4.220229
# 3                   0.573283                0.530186
# 4                 914.925067                3.620890
#
#    handling_equipment_availability  order_fulfillment_status  ...  \
# 0                         0.481294                  0.761166  ...
# 1                         0.620780                  0.196594  ...
# 2                         0.810933                  0.152742  ...
# 3                         0.008525                  0.811885  ...
# 4                         0.020083                  0.053659  ...
#
#    iot_temperature  cargo_condition_status  route_risk_level  \
# 0         0.574400                0.777263          1.182116
# 1        -9.753493                0.091839          9.611988
# 2        -6.491034                0.253529          6.570431
# 3        -0.151276                0.877576          0.548952
# 4         2.429448                0.262081          8.861443
#
#    customs_clearance_time  driver_behavior_score  fatigue_monitoring_score  \
# 0                0.502006               0.033843                  0.978599
# 1                0.966774               0.201725                  0.918586
# 2                0.945627               0.264045                  0.394215
# 3                4.674035               0.362885                  0.905444
# 4                3.445429               0.016957                  0.258702
#
#    disruption_likelihood_score  delay_probability  risk_classification  \
# 0                     0.506152           0.885291        Moderate Risk
# 1                     0.980784           0.544178            High Risk
# 2                     0.998633           0.803322            High Risk
# 3                     0.993320           0.025977            High Risk
# 4                     0.912433           0.991122            High Risk
#
#    delivery_time_deviation
# 0                 9.110682
# 1                 8.175281
# 2                 1.283594
# 3                 9.304897
# 4                 7.752484
#
# [5 rows x 26 columns]

# %% [markdown]
# Visualizar los tipos de datos en cada columna

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32065 entries, 0 to 32064
# Data columns (total 26 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   timestamp                        32065 non-null  object
#  1   vehicle_gps_latitude             32065 non-null  float64
#  2   vehicle_gps_longitude            32065 non-null  float64
#  3   fuel_consumption_rate            32065 non-null  float64
#  4   eta_variation_hours              32065 non-null  float64
#  5   traffic_congestion_level         32065 non-null  float64
#  6   warehouse_inventory_level        32065 non-null  float64
#  7   loading_unloading_time           32065 non-null  float64
#  8   handling_equipment_availability  32065 non-null  float64
#  9   order_fulfillment_status         32065 non-null  float64
#  10  weather_condition_severity       32065 non-null  float64
#  11  port_congestion_level            32065 non-null  float64
#  12  shipping_costs                   32065 non-null  float64
#  13  supplier_reliability_score       32065 non-null  float64
#  14  lead_time_days                   32065 non-null  float64
#  15  historical_demand                32065 non-null  float64
#  16  iot_temperature                  32065 non-null  float64
#  17  cargo_condition_status           32065 non-null  float64
#  18  route_risk_level                 32065 non-null  float64
#  19  customs_clearance_time           32065 non-null  float64
#  20  driver_behavior_score            32065 non-null  float64
#  21  fatigue_monitoring_score         32065 non-null  float64
#  22  disruption_likelihood_score      32065 non-null  float64
#  23  delay_probability                32065 non-null  float64
#  24  risk_classification              32065 non-null  object
#  25  delivery_time_deviation          32065 non-null  float64
# dtypes: float64(24), object(2)
# memory usage: 6.4+ MB

# %% [markdown]
# ***Antes de calcular el SLA, generamos la evaluacion y transformación de los tipos de datos...***

# %%
#  Modificación columna timestamp
df['timestamp'] = pd.to_datetime(df['timestamp']) #Es importante porque se va a calcular SLA por día/mes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32065 entries, 0 to 32064
# Data columns (total 26 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   timestamp                        32065 non-null  datetime64[ns]
#  1   vehicle_gps_latitude             32065 non-null  float64
#  2   vehicle_gps_longitude            32065 non-null  float64
#  3   fuel_consumption_rate            32065 non-null  float64
#  4   eta_variation_hours              32065 non-null  float64
#  5   traffic_congestion_level         32065 non-null  float64
#  6   warehouse_inventory_level        32065 non-null  float64
#  7   loading_unloading_time           32065 non-null  float64
#  8   handling_equipment_availability  32065 non-null  float64
#  9   order_fulfillment_status         32065 non-null  float64
#  10  weather_condition_severity       32065 non-null  float64
#  11  port_congestion_level            32065 non-null  float64
#  12  shipping_costs                   32065 non-null  float64
#  13  supplier_reliability_score       32065 non-null  float64
#  14  lead_time_days                   32065 non-null  float64
#  15  historical_demand                32065 non-null  float64
#  16  iot_temperature                  32065 non-null  float64
#  17  cargo_condition_status           32065 non-null  float64
#  18  route_risk_level                 32065 non-null  float64
#  19  customs_clearance_time           32065 non-null  float64
#  20  driver_behavior_score            32065 non-null  float64
#  21  fatigue_monitoring_score         32065 non-null  float64
#  22  disruption_likelihood_score      32065 non-null  float64
#  23  delay_probability                32065 non-null  float64
#  24  risk_classification              32065 non-null  object
#  25  delivery_time_deviation          32065 non-null  float64
# dtypes: datetime64[ns](1), float64(24), object(1)
# memory usage: 6.4+ MB

# %% [markdown]
# A fin de verificación de datos erróneos cómo: strings vacíos, espacios en blanco y los "null" del tipo texto, se ejecuta la siguiente expresión del tipo Booleano (Valor 0/False)

# %%
df.isnull().sum()
# Out:
# timestamp                          0
# vehicle_gps_latitude               0
# vehicle_gps_longitude              0
# fuel_consumption_rate              0
# eta_variation_hours                0
# traffic_congestion_level           0
# warehouse_inventory_level          0
# loading_unloading_time             0
# handling_equipment_availability    0
# order_fulfillment_status           0
# weather_condition_severity         0
# port_congestion_level              0
# shipping_costs                     0
# supplier_reliability_score         0
# lead_time_days                     0
# historical_demand                  0
# iot_temperature                    0
# cargo_condition_status             0
# route_risk_level                   0
# customs_clearance_time             0
# driver_behavior_score              0
# fatigue_monitoring_score           0
# disruption_likelihood_score        0
# delay_probability                  0
# risk_classification                0
# delivery_time_deviation            0
# dtype: int64

# %% [markdown]
# El dataset posee registros de los años 2021/2022 pero todos los meses del año solo figuran para el 2021 porque le filtramos por este último año: Se crea DataFrame.

# %%
df_2021 = df[df['timestamp'].dt.year == 2021]

# %%
df_2021['timestamp'].dt.year.unique()
# Out:
# array([2021], dtype=int32)

# %%
df.shape
# Out:
# (32065, 26)

# %% [markdown]
# Ver las primeras filas de mi DataFrame

# %%
df_2021.head()
# Out:
#             timestamp  vehicle_gps_latitude  vehicle_gps_longitude  \
# 0 2021-01-01 00:00:00             40.375568             -77.014318
# 1 2021-01-01 01:00:00             33.507818            -117.036902
# 2 2021-01-01 02:00:00             30.020640             -75.269224
# 3 2021-01-01 03:00:00             36.649223             -70.190529
# 4 2021-01-01 04:00:00             30.001279             -70.012195
#
#    fuel_consumption_rate  eta_variation_hours  traffic_congestion_level  \
# 0               5.136512             4.998009                  5.927586
# 1               5.101512             0.984929                  1.591992
# 2               5.090803             4.972665                  8.787765
# 3               8.219558             3.095064                  0.045257
# 4               5.000075             3.216077                  8.004851
#
#    warehouse_inventory_level  loading_unloading_time  \
# 0                 985.716862                4.951392
# 1                 396.700206                1.030379
# 2                 832.408935                4.220229
# 3                   0.573283                0.530186
# 4                 914.925067                3.620890
#
#    handling_equipment_availability  order_fulfillment_status  ...  \
# 0                         0.481294                  0.761166  ...
# 1                         0.620780                  0.196594  ...
# 2                         0.810933                  0.152742  ...
# 3                         0.008525                  0.811885  ...
# 4                         0.020083                  0.053659  ...
#
#    iot_temperature  cargo_condition_status  route_risk_level  \
# 0         0.574400                0.777263          1.182116
# 1        -9.753493                0.091839          9.611988
# 2        -6.491034                0.253529          6.570431
# 3        -0.151276                0.877576          0.548952
# 4         2.429448                0.262081          8.861443
#
#    customs_clearance_time  driver_behavior_score  fatigue_monitoring_score  \
# 0                0.502006               0.033843                  0.978599
# 1                0.966774               0.201725                  0.918586
# 2                0.945627               0.264045                  0.394215
# 3                4.674035               0.362885                  0.905444
# 4                3.445429               0.016957                  0.258702
#
#    disruption_likelihood_score  delay_probability  risk_classification  \
# 0                     0.506152           0.885291        Moderate Risk
# 1                     0.980784           0.544178            High Risk
# 2                     0.998633           0.803322            High Risk
# 3                     0.993320           0.025977            High Risk
# 4                     0.912433           0.991122            High Risk
#
#    delivery_time_deviation
# 0                 9.110682
# 1                 8.175281
# 2                 1.283594
# 3                 9.304897
# 4                 7.752484
#
# [5 rows x 26 columns]

# %% [markdown]
# Ver las últimas filas de mi DataFrame

# %%
df_2021.tail()
# Out:
#                timestamp  vehicle_gps_latitude  vehicle_gps_longitude  \
# 8755 2021-12-31 19:00:00             30.005979             -90.196458
# 8756 2021-12-31 20:00:00             30.203338             -89.293525
# 8757 2021-12-31 21:00:00             30.197144            -115.493986
# 8758 2021-12-31 22:00:00             30.058723             -99.911377
# 8759 2021-12-31 23:00:00             47.339203            -118.254991
#
#       fuel_consumption_rate  eta_variation_hours  traffic_congestion_level  \
# 8755               5.293510            -0.834869                  9.689533
# 8756               5.000710            -1.071880                  3.226226
# 8757               9.378763             4.944122                  9.807176
# 8758               6.575377             1.317836                  5.046628
# 8759               5.000451             4.899140                  5.223284
#
#       warehouse_inventory_level  loading_unloading_time  \
# 8755                 852.093985                2.502879
# 8756                 497.321341                1.083978
# 8757                  13.453240                4.469262
# 8758                  12.801086                1.126800
# 8759                  74.136793                3.020670
#
#       handling_equipment_availability  order_fulfillment_status  ...  \
# 8755                         0.659683                  0.999983  ...
# 8756                         0.000003                  0.217231  ...
# 8757                         0.001874                  0.934957  ...
# 8758                         0.008327                  0.407968  ...
# 8759                         0.000756                  1.000000  ...
#
#       iot_temperature  cargo_condition_status  route_risk_level  \
# 8755        -9.959503                0.686253         10.000000
# 8756        -9.748550                0.073343          0.873882
# 8757        -9.999127                0.000013          2.308961
# 8758        -9.403336                0.183286          9.724184
# 8759        -9.994072                0.793542          1.452409
#
#       customs_clearance_time  driver_behavior_score  fatigue_monitoring_score  \
# 8755                3.214982               0.232630                  0.399165
# 8756                2.183085               0.979909                  0.254921
# 8757                4.433492               0.128435                  0.003857
# 8758                0.785331               0.351352                  0.080906
# 8759                2.155889               0.058355                  0.000483
#
#       disruption_likelihood_score  delay_probability  risk_classification  \
# 8755                     0.985608           0.999979            High Risk
# 8756                     0.827646           0.999968            High Risk
# 8757                     0.917991           0.991617            High Risk
# 8758                     0.998610           0.656978            High Risk
# 8759                     0.893374           0.099085            High Risk
#
#       delivery_time_deviation
# 8755                -0.430182
# 8756                 6.190065
# 8757                 1.740547
# 8758                 3.128893
# 8759                 9.999279
#
# [5 rows x 26 columns]

# %% [markdown]
# Generamos una nueva columna que muestre los meses a partir de nuestra columna timestamp:

# %%
df_2021 = df[df['timestamp'].dt.year == 2021].copy()
df_2021["month"] = df_2021["timestamp"].dt.month_name()

# %%
df_2021.head()
# Out:
#             timestamp  vehicle_gps_latitude  vehicle_gps_longitude  \
# 0 2021-01-01 00:00:00             40.375568             -77.014318
# 1 2021-01-01 01:00:00             33.507818            -117.036902
# 2 2021-01-01 02:00:00             30.020640             -75.269224
# 3 2021-01-01 03:00:00             36.649223             -70.190529
# 4 2021-01-01 04:00:00             30.001279             -70.012195
#
#    fuel_consumption_rate  eta_variation_hours  traffic_congestion_level  \
# 0               5.136512             4.998009                  5.927586
# 1               5.101512             0.984929                  1.591992
# 2               5.090803             4.972665                  8.787765
# 3               8.219558             3.095064                  0.045257
# 4               5.000075             3.216077                  8.004851
#
#    warehouse_inventory_level  loading_unloading_time  \
# 0                 985.716862                4.951392
# 1                 396.700206                1.030379
# 2                 832.408935                4.220229
# 3                   0.573283                0.530186
# 4                 914.925067                3.620890
#
#    handling_equipment_availability  order_fulfillment_status  ...  \
# 0                         0.481294                  0.761166  ...
# 1                         0.620780                  0.196594  ...
# 2                         0.810933                  0.152742  ...
# 3                         0.008525                  0.811885  ...
# 4                         0.020083                  0.053659  ...
#
#    cargo_condition_status  route_risk_level  customs_clearance_time  \
# 0                0.777263          1.182116                0.502006
# 1                0.091839          9.611988                0.966774
# 2                0.253529          6.570431                0.945627
# 3                0.877576          0.548952                4.674035
# 4                0.262081          8.861443                3.445429
#
#    driver_behavior_score  fatigue_monitoring_score  \
# 0               0.033843                  0.978599
# 1               0.201725                  0.918586
# 2               0.264045                  0.394215
# 3               0.362885                  0.905444
# 4               0.016957                  0.258702
#
#    disruption_likelihood_score  delay_probability  risk_classification  \
# 0                     0.506152           0.885291        Moderate Risk
# 1                     0.980784           0.544178            High Risk
# 2                     0.998633           0.803322            High Risk
# 3                     0.993320           0.025977            High Risk
# 4                     0.912433           0.991122            High Risk
#
#    delivery_time_deviation    month
# 0                 9.110682  January
# 1                 8.175281  January
# 2                 1.283594  January
# 3                 9.304897  January
# 4                 7.752484  January
#
# [5 rows x 27 columns]

# %% [markdown]
# # Comenzando con el cálculo de SLA
# Primero creamos la categorización:
#
#
# *   ≤ 0 → Entrega en tiempo (cumple SLA)
# *   > 0 → Entrega con demora (no cumple SLA)

# %%
df_2021["SLA_status"] = df_2021["delivery_time_deviation"].apply(
    lambda x: "CUMPLE" if x <= 0 else "NO CUMPLE"
)

# %% [markdown]
# Crear columna SLA numérica Donde:
#
# *   1 = Cumple
# *   0 = No cumple

# %%
df_2021["SLA"] = df_2021["delivery_time_deviation"].apply(
    lambda x: 1 if x <= 0 else 0
)

# %% [markdown]
# Calculo de SLA de todo el año 2021

# %%
sla_total_2021 = df_2021["SLA"].mean() * 100
print(f"SLA 2021: {sla_total_2021:.2f}%")
# Out:
# SLA 2021: 17.76%

# %% [markdown]
# DataFrame para graficar: SLA por mes

# %%
sla_mensual = df_2021.groupby("month")["SLA"].mean() * 100
sla_mensual = sla_mensual.reset_index()

# %%
df_2021.head()
# Out:
#             timestamp  vehicle_gps_latitude  vehicle_gps_longitude  \
# 0 2021-01-01 00:00:00             40.375568             -77.014318
# 1 2021-01-01 01:00:00             33.507818            -117.036902
# 2 2021-01-01 02:00:00             30.020640             -75.269224
# 3 2021-01-01 03:00:00             36.649223             -70.190529
# 4 2021-01-01 04:00:00             30.001279             -70.012195
#
#    fuel_consumption_rate  eta_variation_hours  traffic_congestion_level  \
# 0               5.136512             4.998009                  5.927586
# 1               5.101512             0.984929                  1.591992
# 2               5.090803             4.972665                  8.787765
# 3               8.219558             3.095064                  0.045257
# 4               5.000075             3.216077                  8.004851
#
#    warehouse_inventory_level  loading_unloading_time  \
# 0                 985.716862                4.951392
# 1                 396.700206                1.030379
# 2                 832.408935                4.220229
# 3                   0.573283                0.530186
# 4                 914.925067                3.620890
#
#    handling_equipment_availability  order_fulfillment_status  ...  \
# 0                         0.481294                  0.761166  ...
# 1                         0.620780                  0.196594  ...
# 2                         0.810933                  0.152742  ...
# 3                         0.008525                  0.811885  ...
# 4                         0.020083                  0.053659  ...
#
#    customs_clearance_time  driver_behavior_score  fatigue_monitoring_score  \
# 0                0.502006               0.033843                  0.978599
# 1                0.966774               0.201725                  0.918586
# 2                0.945627               0.264045                  0.394215
# 3                4.674035               0.362885                  0.905444
# 4                3.445429               0.016957                  0.258702
#
#    disruption_likelihood_score  delay_probability  risk_classification  \
# 0                     0.506152           0.885291        Moderate Risk
# 1                     0.980784           0.544178            High Risk
# 2                     0.998633           0.803322            High Risk
# 3                     0.993320           0.025977            High Risk
# 4                     0.912433           0.991122            High Risk
#
#    delivery_time_deviation    month  SLA_status  SLA
# 0                 9.110682  January   NO CUMPLE    0
# 1                 8.175281  January   NO CUMPLE    0
# 2                 1.283594  January   NO CUMPLE    0
# 3                 9.304897  January   NO CUMPLE    0
# 4                 7.752484  January   NO CUMPLE    0
#
# [5 rows x 29 columns]

# %%
df_2021["delivery_time_deviation"].describe()
# Out:
# count    8760.000000
# mean        5.240849
# std         4.167040
# min        -1.999998
# 25%         1.289632
# 50%         6.253691
# 75%         9.318613
# max        10.000000
# Name: delivery_time_deviation, dtype: float64

# %% [markdown]
# Cálculo duración SLA: Definimos SLA

# %%
df_2021["SLA"] = df_2021["delivery_time_deviation"] <= 0
df_2021["SLA"].mean() * 100
# Out:
# np.float64(17.76255707762557)

# %%
df_2021["delay_duration"] = pd.to_timedelta(
    df_2021["delivery_time_deviation"],
    unit="h"
)

# %%
df_2021.head()
# Out:
#             timestamp  vehicle_gps_latitude  vehicle_gps_longitude  \
# 0 2021-01-01 00:00:00             40.375568             -77.014318
# 1 2021-01-01 01:00:00             33.507818            -117.036902
# 2 2021-01-01 02:00:00             30.020640             -75.269224
# 3 2021-01-01 03:00:00             36.649223             -70.190529
# 4 2021-01-01 04:00:00             30.001279             -70.012195
#
#    fuel_consumption_rate  eta_variation_hours  traffic_congestion_level  \
# 0               5.136512             4.998009                  5.927586
# 1               5.101512             0.984929                  1.591992
# 2               5.090803             4.972665                  8.787765
# 3               8.219558             3.095064                  0.045257
# 4               5.000075             3.216077                  8.004851
#
#    warehouse_inventory_level  loading_unloading_time  \
# 0                 985.716862                4.951392
# 1                 396.700206                1.030379
# 2                 832.408935                4.220229
# 3                   0.573283                0.530186
# 4                 914.925067                3.620890
#
#    handling_equipment_availability  order_fulfillment_status  ...  \
# 0                         0.481294                  0.761166  ...
# 1                         0.620780                  0.196594  ...
# 2                         0.810933                  0.152742  ...
# 3                         0.008525                  0.811885  ...
# 4                         0.020083                  0.053659  ...
#
#    driver_behavior_score  fatigue_monitoring_score  \
# 0               0.033843                  0.978599
# 1               0.201725                  0.918586
# 2               0.264045                  0.394215
# 3               0.362885                  0.905444
# 4               0.016957                  0.258702
#
#    disruption_likelihood_score  delay_probability  risk_classification  \
# 0                     0.506152           0.885291        Moderate Risk
# 1                     0.980784           0.544178            High Risk
# 2                     0.998633           0.803322            High Risk
# 3                     0.993320           0.025977            High Risk
# 4                     0.912433           0.991122            High Risk
#
#    delivery_time_deviation    month  SLA_status    SLA  \
# 0                 9.110682  January   NO CUMPLE  False
# 1                 8.175281  January   NO CUMPLE  False
# 2                 1.283594  January   NO CUMPLE  False
# 3                 9.304897  January   NO CUMPLE  False
# 4                 7.752484  January   NO CUMPLE  False
#
#              delay_duration
# 0 0 days 09:06:38.454556867
# 1 0 days 08:10:31.011382858
# 2 0 days 01:17:00.937541018
# 3 0 days 09:18:17.629814120
# 4 0 days 07:45:08.941901544
#
# [5 rows x 30 columns]

# %% [markdown]
# *A fin de comenzar con la visualización, generamos una AGRUPACIÓN por el MES y el ESTADO DE SLA*

# %%
tabla_sla = df_2021.groupby(["month", "SLA_status"]).size().unstack()
tabla_sla
# Out:
# SLA_status  CUMPLE  NO CUMPLE
# month
# April          133        587
# August         128        616
# December       116        628
# February       128        544
# January        127        617
# July           129        615
# June           134        586
# March          136        608
# May            136        608
# November       142        578
# October        116        628
# September      131        589

# %% [markdown]
# *Ordenamos cronologicamente los meses...*

# %%
orden_meses = [
    "January", "February", "March", "April",
    "May", "June", "July", "August",
    "September", "October", "November", "December"
]

tabla_sla = tabla_sla.reindex(orden_meses)
tabla_sla
# Out:
# SLA_status  CUMPLE  NO CUMPLE
# month
# January        127        617
# February       128        544
# March          136        608
# April          133        587
# May            136        608
# June           134        586
# July           129        615
# August         128        616
# September      131        589
# October        116        628
# November       142        578
# December       116        628

# %% [markdown]
# *Nuestro primer gráfico*...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %% [markdown]
# **El siguiene gráfico de barras, representa la cantidad total de tareas por los diferentes meses del año 2021, Dividida en las Categorias: CUMPLE / NO CUMPLE**

# %%
tabla_sla.plot(kind="bar")

plt.title("Cumplimiento de SLA por Mes año 2021")
plt.xlabel("Mes")
plt.ylabel("Cantidad de entregas")
plt.xticks(rotation=45)
plt.legend(title="Estado SLA")

plt.show()

# %% [markdown]
# **El siguiente gráfico de columna apiladas representa el 100% de las entregas de un mes, dividida proporcionalmente en las Categorias: CUMPLE / NO CUMPLE.**

# %%
tabla_sla = df_2021.groupby(["month", "SLA_status"]).size().unstack()
tabla_pct = tabla_sla.div(tabla_sla.sum(axis=1), axis=0) * 100

# %%
tabla_pct.plot(kind="bar", stacked=True)

plt.title("Distribución % SLA por Mes Año 2021")
plt.ylabel("Porcentaje (%)")
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# *Utilizamos pie chart para mostrar el cumplimiento ANUAL*
#
# ---

# %%
total_anual = df_2021["SLA_status"].value_counts()

plt.pie(total_anual, labels=total_anual.index, autopct="%1.1f%%")
plt.title("Distribución Total SLA - Año 2021")
plt.show()

# %%
total_anual = total_anual[["CUMPLE", "NO CUMPLE"]]

colores = ["#06CA00", "#FF3A3A"]

plt.pie(
    total_anual,
    labels=total_anual.index,
    autopct="%1.1f%%",
    colors=colores
)

plt.title("Distribución Total SLA - Año 2021")

plt.legend(
    title="Descripción",
    labels=["Utilizamos pie chart para mostrar el cumplimiento ANUAL"],
    loc="lower center",
    bbox_to_anchor=(0.5, -0.1)
)

plt.show()

# %% [markdown]
# *Seaborn: diagrama de caja (boxplot), analisis la distribución mensual de la variable delivery_time_deviation. Esta visualización permite observar la mediana, el rango intercuartílico y la presencia de valores atípicos en cada mes, facilitando la comparación del comportamiento estadístico de las demoras a lo largo del año 2021.*

# %%
plt.figure(figsize=(10,6))

sns.boxplot(
    data=df_2021,
    x="month",
    y="delivery_time_deviation",
    hue="month",
    palette="YlOrRd",
    legend=False
)

plt.xticks(rotation=45)
plt.title("Distribución de Demoras por Mes")
plt.show()

# %% [markdown]
# *Heatmap: Se utilizó un mapa de calor (heatmap) para representar el porcentaje de cumplimiento del SLA por mes. Esta visualización emplea una escala de colores para reflejar la intensidad de los valores, permitiendo identificar de manera inmediata los meses con mejor y peor desempeño.*
#
# *   Filas → Meses
#
# *   Columnas → Estado del SLA (CUMPLE / NO CUMPLE)
# *   Valores dentro de cada celda → Porcentaje
#
#
# *  Color → Intensidad del cumplimiento

# %%
plt.figure(figsize=(8,6))

sns.heatmap(
    tabla_pct,
    annot=True,
    fmt=".1f",
    cmap="RdYlGn"
)

plt.title("Heatmap % Cumplimiento SLA por Mes")
plt.show()
